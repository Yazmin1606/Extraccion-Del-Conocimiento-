# %% [markdown]
# # Datos sinteticos
# # Utilizacion de la libreria FAKER
# *Autor: Karol Yazmin Aguilar Hernandez*

# %%
import pandas as pd
import numpy as np 
import random

# %%
from faker import Faker

# %%
pip install faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Creamos una instancia de Faker
fake = Faker("es_MX")

# %%
# Generamos datos sinteticos a datos falsos 
datos = []
for  i in range(100):
        datos. append(
            {
                "id_usuario": i + 1,
                "nombre": fake.name(),
                "correo": fake.email(),
                "edad": random.randint(18,65),
                "seguidores": random.randint(50,5000),
                "plataforma": random.choice(["TikTok","Instagram","YouTube"])
            }
        )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                               nombre  \
# 0            1       Ángela Francisca Matos Esparza
# 1            2               Yolanda Indira Pedraza
# 2            3     Citlali Esmeralda Yáñez Bermúdez
# 3            4             Berta Susana Rojo Gaitán
# 4            5      Julio César Felix Osorio Roybal
# ..         ...                                  ...
# 95          96                       Sonia Granados
# 96          97                        Sergio Prieto
# 97          98                   Adán Mauricio Mora
# 98          99  Amador Fernando Holguín de la Garza
# 99         100         Inés Judith Tijerina Sauceda
#
#                               correo  edad  seguidores plataforma
# 0              rojasabel@example.org    55         769     TikTok
# 1                njuarez@example.com    49        3232     TikTok
# 2          adrianaibarra@example.com    52        2320    YouTube
# 3   miramontesmaria-jose@example.org    29         894    YouTube
# ...

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    str
#  2   correo      100 non-null    str
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 4.8 KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   41.110000  2317.240000
# std     29.011492   13.835903  1435.061862
# min      1.000000   18.000000    50.000000
# 25%     25.750000   28.750000  1067.500000
# 50%     50.500000   42.500000  2250.500000
# 75%     75.250000   51.250000  3482.250000
# max    100.000000   65.000000  4962.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario         nombre                   correo        edad  \
# count   100.000000            100                      100  100.000000
# unique         NaN            100                      100         NaN
# top            NaN  Hernán Suárez  castromitzy@example.com         NaN
# freq           NaN              1                        1         NaN
# mean     50.500000            NaN                      NaN   38.540000
# std      29.011492            NaN                      NaN   13.743259
# min       1.000000            NaN                      NaN   18.000000
# 25%      25.750000            NaN                      NaN   26.000000
# 50%      50.500000            NaN                      NaN   37.000000
# 75%      75.250000            NaN                      NaN   50.000000
# max     100.000000            NaN                      NaN   65.000000
#
#          seguidores plataforma
# count    100.000000        100
# unique          NaN          3
# ...

# %%
#Graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Graficamos como se generaron las edades 
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribución de edades")
plt.show()

# %%
# Graficamos la cantidad de usuarios por plataforma 
plt.figure(figsize = (8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidada de usuarios por plataforma")
plt.show()
